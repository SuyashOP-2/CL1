# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data = pd.read_csv("Telecom_Customer_Churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print("Number od Duplicate Before removing duplicates: ",len(data))
# Out:
# Number od Duplicate Before removing duplicates:  7043

# %%
cleaned_data = data.drop_duplicates()
print("Number of rows after removing duplicates:", len(cleaned_data))
# Out:
# Number of rows after removing duplicates: 7043

# %%
## statistical survey

cleaned_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
sns.boxplot(data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.boxplot(data['tenure'])
plt.show()

# %%
## scaling and encoding
encoder = LabelEncoder()
scalar = StandardScaler()

columns = data.columns

for column in columns:
    data[column] = encoder.fit_transform(data[column])


data[columns] = scalar.fit_transform(data[columns])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
data.head()
# Out:
#    customerID    gender  SeniorCitizen   Partner  Dependents    tenure  \
# 0    0.911890 -1.009559      -0.439916  1.034530   -0.654012 -1.277445
# 1    0.216906  0.990532      -0.439916 -0.966622   -0.654012  0.066327
# 2   -0.470701  0.990532      -0.439916 -0.966622   -0.654012 -1.236724
# 3    0.990587  0.990532      -0.439916 -0.966622   -0.654012  0.514251
# 4    1.470632 -1.009559      -0.439916 -0.966622   -0.654012 -1.236724
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0     -3.054010       0.062723        -1.183234       -0.918838  ...
# 1      0.327438      -0.991588        -1.183234        1.407321  ...
# 2      0.327438      -0.991588        -1.183234        1.407321  ...
# 3     -3.054010       0.062723        -1.183234        1.407321  ...
# 4      0.327438      -0.991588         0.172250       -0.918838  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
# Drop the column 
# Rename the column

# Handling outliers

data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
dropped = data.drop("OnlineBackup", axis = 1 )
dropped.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
dropped['newCol'] = data['OnlineBackup']

# %%
dropped.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'newCol'],
#       dtype='object')

# %%
dropped.head()
# Out:
#    customerID    gender  SeniorCitizen   Partner  Dependents    tenure  \
# 0    0.911890 -1.009559      -0.439916  1.034530   -0.654012 -1.277445
# 1    0.216906  0.990532      -0.439916 -0.966622   -0.654012  0.066327
# 2   -0.470701  0.990532      -0.439916 -0.966622   -0.654012 -1.236724
# 3    0.990587  0.990532      -0.439916 -0.966622   -0.654012  0.514251
# 4    1.470632 -1.009559      -0.439916 -0.966622   -0.654012 -1.236724
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0     -3.054010       0.062723        -1.183234       -0.918838  ...
# 1      0.327438      -0.991588        -1.183234        1.407321  ...
# 2      0.327438      -0.991588        -1.183234        1.407321  ...
# 3     -3.054010       0.062723        -1.183234        1.407321  ...
# 4      0.327438      -0.991588         0.172250       -0.918838  ...
#
#    TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# ...

# %%
# Handling Outliers

mean = np.mean(data)
std = np.std(data)
zscore = (data - mean) / std
threshold = 3
data[np.abs(zscore) < threshold]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#       customerID    gender  SeniorCitizen   Partner  Dependents    tenure  \
# 0       0.911890 -1.009559      -0.439916  1.034530   -0.654012 -1.277445
# 1       0.216906  0.990532      -0.439916 -0.966622   -0.654012  0.066327
# 2      -0.470701  0.990532      -0.439916 -0.966622   -0.654012 -1.236724
# 3       0.990587  0.990532      -0.439916 -0.966622   -0.654012  0.514251
# 4       1.470632 -1.009559      -0.439916 -0.966622   -0.654012 -1.236724
# ...          ...       ...            ...       ...         ...       ...
# ...
